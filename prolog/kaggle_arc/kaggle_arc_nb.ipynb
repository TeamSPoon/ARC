# %%
from pyswip import Prolog
prolog = Prolog()
prolog.assertz("father(michael,john)")
prolog.assertz("father(michael,gina)")

# %%
list(prolog.query("father(michael,X)")) == [{'X': 'john'}, {'X': 'gina'}]
for soln in prolog.query("father(X,Y)"):
    print(soln["X"], "is the father of", soln["Y"])
# Out:
# michael is the father of john
# michael is the father of gina

# %%
for soln in prolog.query("consult(kaggle_arc)"): print()
# Out:
# % init_phase(after_load).
# current_prolog_flag(argv,[])
# %~ call_in_thread('user:wdmsg(call_in_thread)',user,wdmsg(call_in_thread))
# %~ call_in_thread.
# %~ call_in_thread
# program=[ grid_size(In,InH,InV),
#           grid_size(Out,OutH,OutV),
#           InArea is InH*InV,
#           OutArea is OutH*OutV,
#           ratio_for(RatioArea,OutArea,InArea),
#           max_min(OutArea,InArea,BothMaxArea,BothMinArea),
#           mass(In,InMass),
#           mass(Out,OutMass),
#           ratio_for(DeltaMass,OutMass,InMass),
#           unique_color_count(In,InColorLen),
#           unique_color_count(Out,OutColorLen),
#           ratio_for(RatioColorLen,OutColorLen,InColorLen),
#           unique_colors(In,InColors),
#           unique_colors(Out,OutColors),
#           intersection( InColors,
#             OutColors, SharedColors,InSpecificColors,
#             OutSpecificColors),
#           append( [InSpecificColors,SharedColors,OutSpecificColors],
#             Include_Append_AllColors),
#           nop(dont_include(Include_Append_AllColors)),
#           sort_safe(Include_Append_AllColors,AllColors),
#           my_maplist( length,
#             [ InColors, OutColors,SharedColors,
#                  InSpecificColors, OutSpecificColors, AllColors],
#             [ InColorsLen, OutColorsLen,SharedColorsLen,
#                      InSpecificColorsLen, OutSpecificColorsLen, AllColorsLen]),
#           ratio_for(RescaleH,OutH,InH),
#           ratio_for(RescaleV,OutV,InV),
#           ratio_for(InDensity,InMass,InArea),
#           ratio_for(OutDensity,OutMass,OutArea),
#           ratio_for(DeltaDensity,OutDensity,InDensity),
#           max_min(OutH,OutV,OutMaxHV,Min_OutMaxHV),
#           max_min(InH,InV,InMaxHV,Min_MaxHV),
#           OutMaxHVArea is OutMaxHV*OutMaxHV,
#           InMaxHVArea is InMaxHV*InMaxHV,
#           ratio_for(RatioMaxHVArea,OutMaxHVArea,InMaxHVArea),
#           max_min(InMaxHVArea,OutMaxHVArea,BothMaxHVAreaMax,BothMaxHVAreaMin),
#           ratio_for(RatioBothMaxHVArea,BothMaxHVAreaMax,BothMaxHVAreaMin)]
# 		in=In
# 		in_h=InH
# 		in_v=InV
# 		out=Out
# 		out_h=OutH
# 		out_v=OutV
# 		in_area=InArea
# 		out_area=OutArea
# 		ratio_area=RatioArea
# 		both_max_area=BothMaxArea
# 		both_min_area=BothMinArea
# 		in_mass=InMass
# 		out_mass=OutMass
# 		delta_mass=DeltaMass
# 		in_color_len=InColorLen
# 		out_color_len=OutColorLen
# 		ratio_color_len=RatioColorLen
# 		in_colors=InColors
# 		out_colors=OutColors
# 		shared_colors=SharedColors
# 		in_specific_colors=InSpecificColors
# 		out_specific_colors=OutSpecificColors
# 		all_colors=AllColors
# 		in_colors_len=InColorsLen
# 		out_colors_len=OutColorsLen
# 		shared_colors_len=SharedColorsLen
# 		in_specific_colors_len=InSpecificColorsLen
# 		out_specific_colors_len=OutSpecificColorsLen
# 		all_colors_len=AllColorsLen
# 		rescale_h=RescaleH
# 		rescale_v=RescaleV
# 		in_density=InDensity
# 		out_density=OutDensity
# 		delta_density=DeltaDensity
# 		out_max_hv=OutMaxHV
# 		in_max_hv=InMaxHV
# 		out_max_hv_area=OutMaxHVArea
# 		in_max_hv_area=InMaxHVArea
# 		ratio_max_hv_area=RatioMaxHVArea
# 		both_max_hv_area_max=BothMaxHVAreaMax
# 		both_max_hv_area_min=BothMaxHVAreaMin
# 		ratio_both_max_hv_area=RatioBothMaxHVArea
# synthesized(user:clear_saveable_test_info)
# synthesized(user:print_test_file_hints)
# synthesized(user:print_test_hints)
# synthesized(user:is_encode_tst)
# synthesized(user:test_encoders_mining)
# synthesized(user:invoke_arc_cmd)
# synthesized(user:save_test_hints)
# synthesized(user:clear_test_now)
# synthesized(user:whole_ndividuator)
# synthesized(user:each_ndividuator)
# synthesized(user:show_task_pairs)
# synthesized(user:clear_saveable_test_info_now)
# synthesized(user:ndividuator_logicmoo)
# synthesized(user:test_encoders)
# synthesized(user:ndividuator)
# synthesized(user:parcCmt)
# synthesized(user:print_whole_test)
# synthesized(user:invoke_n_v)
# synthesized(user:test_encoder_for_simple_output)
# %~ default.
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:12:
# Warning:    Redefined static procedure area/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:10
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:14:
# Warning:    Redefined static procedure vis_area/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:12
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:16:
# Warning:    Redefined static procedure area_or_len/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:14
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:19:
# Warning:    Redefined static procedure density/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:17
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:24:
# Warning:    Redefined static procedure into_gridoid0/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:20
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:30:
# Warning:    Redefined static procedure into_gridoid/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:25
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:38:
# Warning:    Redefined static procedure test_grav_rot/0
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:33
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:39:
# Warning:    Redefined static procedure test_grav_rot/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:34
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:51:
# Warning:    Redefined static procedure flip_Once/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:36
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:63:
# Warning:    Redefined static procedure flip_Many/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:46
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:90:
# Warning:    Redefined static procedure grid_mass_ints/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:62
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:103:
# Warning:    Redefined static procedure normal_w/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:49
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:161:
# Warning:    Redefined static procedure grav_rot/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:68
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:176:
# Warning:    Redefined static procedure best_grav_rot_grid/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:81
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:186:
# Warning:    Redefined static procedure length_safe/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:87
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:188:
# Warning:    Redefined static procedure do_my_check_args/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:89
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:189:
# Warning:    Redefined static procedure my_check_args/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:90
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:192:
# Warning:    Redefined static procedure rot_mass/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:93
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:207:
# Warning:    Redefined static procedure map_row_size/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:108
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:220:
# Warning:    Redefined static procedure is_top_heavy/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:130
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:221:
# Warning:    Redefined static procedure is_left_heavy/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:131
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:222:
# Warning:    Redefined static procedure split_50_v/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:132
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:225:
# Warning:    Redefined static procedure grav_mass/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:121
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:229:
# Warning:    Redefined static procedure tips_to_rot/5
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:125
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:235:
# Warning:    Redefined static procedure ensure_dir/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:136
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:236:
# Warning:    Redefined static procedure ensure_int/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:137
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:237:
# Warning:    Redefined static procedure gravity/0
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:138
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:238:
# Warning:    Redefined static procedure gravity/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:139
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:247:
# Warning:    Redefined static procedure gravity_1_n_0/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:148
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:256:
# Warning:    Redefined static procedure any_xform/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:157
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:278:
# Warning:    Redefined static procedure grid_xform/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:179
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:281:
# Warning:    Redefined static procedure apply_transformer/5
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:182
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:286:
# Warning:    Redefined static procedure get_spatial_xformer/5
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:187
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:292:
# Warning:    Redefined static procedure grid_same/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:193
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:293:
# Warning:    Redefined static procedure same_grid/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:194
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:294:
# Warning:    Redefined static procedure sameR/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:195
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:296:
# Warning:    Redefined static procedure test_rot/0
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:197
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:300:
# Warning:    Redefined static procedure rot90/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:201
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:301:
# Warning:    Redefined static procedure rot180/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:202
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:302:
# Warning:    Redefined static procedure rot270/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:203
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:303:
# Warning:    Redefined static procedure flipH/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:204
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:304:
# Warning:    Redefined static procedure flipV/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:205
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:305:
# Warning:    Redefined static procedure flipD/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:206
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:307:
# Warning:    Redefined static procedure flipDV/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:207
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:308:
# Warning:    Redefined static procedure flipDH/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:208
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:309:
# Warning:    Redefined static procedure flipDHV/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:209
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:312:
# Warning:    Redefined static procedure nsew_edges/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:210
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:314:
# Warning:    Redefined static procedure grid_edges_fresh/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:213
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:338:
# Warning:    Redefined static procedure grid_rot90/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:234
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:339:
# Warning:    Redefined static procedure grid_rot180/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:235
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:340:
# Warning:    Redefined static procedure grid_rot270/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:236
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:341:
# Warning:    Redefined static procedure grid_flipH/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:237
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:342:
# Warning:    Redefined static procedure grid_flipV/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:238
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:344:
# Warning:    Redefined static procedure grid_flipDV/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:240
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:345:
# Warning:    Redefined static procedure grid_flipDH/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:241
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:346:
# Warning:    Redefined static procedure grid_flipDHV/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:242
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:348:
# Warning:    Redefined static procedure grid_flipD/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:244
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:383:
# Warning:    Redefined static procedure nav/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:260
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:388:
# Warning:    Redefined static procedure n_s_e_w/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:265
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:394:
# Warning:    Redefined static procedure move_dir/8
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:271
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:396:
# Warning:    Redefined static procedure reverse_nav/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:273
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:398:
# Warning:    Redefined static procedure is_non_diag/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:275
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:401:
# Warning:    Redefined static procedure is_diag/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:278
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:404:
# Warning:    Redefined static procedure rot_right_90/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:281
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:405:
# Warning:    Redefined static procedure rot_left_90/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:282
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:407:
# Warning:    Redefined static procedure rot_right_135/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:284
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:408:
# Warning:    Redefined static procedure rot_left_135/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:285
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:410:
# Warning:    Redefined static procedure rot_right_45/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:287
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:411:
# Warning:    Redefined static procedure rot_left_45/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:288
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:414:
# Warning:    Redefined static procedure w_in_45/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:291
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:418:
# Warning:    Redefined static procedure w_in_90/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:295
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:423:
# Warning:    Redefined static procedure after_dir_check/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:300
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:427:
# Warning:    Redefined static procedure after_dir_check_go_nsew/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:304
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:434:
# Warning:    Redefined static procedure after_dir_check_diag/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:311
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:441:
# Warning:    Redefined static procedure facing_triangles/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:318
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:447:
# Warning:    Redefined static procedure surround_3x3/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:324
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:454:
# Warning:    Redefined static procedure move_above_itself/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:331
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:456:
# Warning:    Redefined static procedure move_rightof_itself/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:333
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:461:
# Warning:    Redefined static procedure move_dir_itself/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:338
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:465:
# Warning:    Redefined static procedure move_dir_object/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:342
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:467:
# Warning:    Redefined static procedure move_scale_dir_object/6
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:344
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:472:
# Warning:    Redefined static procedure move_scale_dir_object/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:349
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:475:
# Warning:    Redefined static procedure move_object/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:352
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:484:
# Warning:    Redefined static procedure is_input/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:361
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:492:
# Warning:    Redefined static procedure show_vm_changes/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:368
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:496:
# Warning:    Redefined static procedure show_object_changes/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:372
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:502:
# Warning:    Redefined static procedure show_point_changes/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:378
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:508:
# Warning:    Redefined static procedure show_grid_changes/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:384
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:514:
# Warning:    Redefined static procedure print_side_by_side_d/6
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:390
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:522:
# Warning:    Redefined static procedure is_physical_object/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:442
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:539:
# Warning:    Redefined static procedure find_engulfs/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:540
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:540:
# Warning:    Redefined static procedure find_overlaps/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:451
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:541:
# Warning:    Redefined static procedure find_touches/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:399
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:542:
# Warning:    Redefined static procedure find_sees/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:421
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:697:
# Warning:    Redefined static procedure better_sdir/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:466
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:718:
# Warning:    Redefined static procedure find_contained_points/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:589
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:721:
# Warning:    Redefined static procedure find_contained_points/7
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:592
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:740:
# Warning:    Redefined static procedure mention_inside/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:611
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:744:
# Warning:    Redefined static procedure find_contained_points/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:615
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:752:
# Warning:    Redefined static procedure object_surrounds_point/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:623
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:756:
# Warning:    Redefined static procedure point_in_obj_view/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:627
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:764:
# Warning:    Redefined static procedure scan_to_colider1/5
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:635
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:771:
# Warning:    Redefined static procedure scan_to_colider/5
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:642
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics.pl:780:
# Warning:    Redefined static procedure replace_i_each/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_physics_dpg.pl:651
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_individuation_pbox_dpg.pl:64:
# Warning:    Singleton variables: [Sizes_L_S]
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_prior_groups.pl:1570:
# Warning:    Singleton variables: [N1,IL]
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_individuation.pl:2208:
# Warning:    Singleton variables: [ObjsB]
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:37:
# Warning:    Redefined static procedure test_supergrid/0
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:33
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:42:
# Warning:    Redefined static procedure print_directive/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:36
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:43:
# Warning:    Redefined static procedure write_intermediatre_header/0
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:37
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:49:
# Warning:    Redefined static procedure print_ref/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:43
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:55:
# Warning:    Redefined static procedure clsbake/0
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:49
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:63:
# Warning:    Redefined static procedure gen_gids/0
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:55
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:67:
# Warning:    Redefined static procedure gen_gids/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:56
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:177:
# Warning:    Redefined static procedure deduce_shapes/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:84
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:180:
# Warning:    Redefined static procedure test_deduce_grid_shapes/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:87
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:185:
# Warning:    Redefined static procedure print_hybrid_set/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:92
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:191:
# Warning:    Redefined static procedure print_hybrid_grid/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:98
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:199:
# Warning:    Redefined static procedure individuate_pairs_from_hints/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:101
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:204:
# Warning:    Redefined static procedure individuate_pair_here/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:106
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:210:
# Warning:    Redefined static procedure print_all_info_for_test/0
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:117
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:304:
# Warning:    Redefined static procedure show_reduced_io_rarely/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:111
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:311:
# Warning:    Redefined static procedure show_reduced_io/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:130
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:333:
# Warning:    Redefined static procedure mapgridish/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:161
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:336:
# Warning:    Redefined static procedure reduce_grids_io/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:164
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:338:
# Warning:    Redefined static procedure interesting_ops/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:167
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:344:
# Warning:    Redefined static procedure reduce_grids_area_io/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:171
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:369:
# Warning:    Redefined static procedure maybe_easy/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:197
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:378:
# Warning:    Redefined static procedure color_subst/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:219
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:386:
# Warning:    Redefined static procedure guess_board/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:236
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:389:
# Warning:    Redefined static procedure show_recolor/5
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:249
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:460:
# Warning:    Redefined static procedure obj_into_cells/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:320
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:468:
# Warning:    Redefined static procedure show_found/6
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:328
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:472:
# Warning:    Redefined static procedure show_found2/6
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:332
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:479:
# Warning:    Redefined static procedure save_grid_hints/0
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:339
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:485:
# Warning:    Redefined static procedure hint_functor/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:345
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:494:
# Warning:    Redefined static procedure hint_into_data/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:354
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:502:
# Warning:    Redefined static procedure relax_hint/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:362
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:512:
# Warning:    Redefined static procedure relax_arg/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:369
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:521:
# Warning:    Redefined static procedure add_xform_maybe/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:377
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:529:
# Warning:    Redefined static procedure add_hint/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:385
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:532:
# Warning:    Redefined static procedure assert_test_property/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:388
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:552:
# Warning:    Redefined static procedure compute_and_show_test_hints/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:406
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:586:
# Warning:    Redefined static procedure ptv1/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:428
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:599:
# Warning:    Redefined static procedure needs_bold/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:436
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:601:
# Warning:    Redefined static procedure ptv11/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:438
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:608:
# Warning:    Redefined static procedure has_spec_value/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:442
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:615:
# Warning:    Redefined static procedure in_smaller_than_out/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:449
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:617:
# Warning:    Redefined static procedure op_op/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:451
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:619:
# Warning:    Redefined static procedure v_area/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:453
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:622:
# Warning:    Redefined static procedure detect_all_training_hints/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:205
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:635:
# Warning:    Redefined static procedure training_only_examples/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:211
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:637:
# Warning:    Redefined static procedure detect_pair_hints/4
# ...
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:993:
# Warning:    Redefined static procedure count_C/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:779
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:995:
# Warning:    Redefined static procedure ensure_arc_test_properties/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:781
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:999:
# Warning:    Redefined static procedure input_objects_first/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:785
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1005:
# Warning:    Redefined static procedure input_expands_into_output/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:790
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1061:
# Warning:    Redefined static procedure into_color_ord/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:844
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1067:
# Warning:    Redefined static procedure grid_hint_iso/9
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:850
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1094:
# Warning:    Redefined static procedure termsub_to_atom/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:877
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1098:
# Warning:    Redefined static procedure fix_iz/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:881
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1105:
# Warning:    Redefined static procedure rinfo/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:888
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1123:
# Warning:    Redefined static procedure grid_color_hint/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:906
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1133:
# Warning:    Redefined static procedure comp_o/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:916
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1137:
# Warning:    Redefined static procedure entire_row/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:919
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1139:
# Warning:    Redefined static procedure mentire_row/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:921
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1142:
# Warning:    Redefined static procedure type_hint_pred/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:924
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1143:
# Warning:    Redefined static procedure grid_area/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:925
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1145:
# Warning:    Redefined static procedure remove_color_if_same/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:927
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1149:
# Warning:    Redefined static procedure has_xy_columns/6
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:931
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1156:
# Warning:    Redefined static procedure has_xy_chunks/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:938
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1162:
# Warning:    Redefined static procedure grid_x_y_area/5
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:944
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1167:
# Warning:    Redefined static procedure gather_chunks/9
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:949
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1185:
# Warning:    Redefined static procedure conjoin_color/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:967
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1187:
# Warning:    Redefined static procedure x_columns/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:969
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1188:
# Warning:    Redefined static procedure y_rows/2
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:970
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1190:
# Warning:    Redefined static procedure has_x_columns/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:972
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1191:
# Warning:    Redefined static procedure has_y_rows/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:973
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1194:
# Warning:    Redefined static procedure has_y_rowz/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:976
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1203:
# Warning:    Redefined static procedure has_y_columns1/4
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:985
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1217:
# Warning:    Redefined static procedure illegal_column_data1/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:999
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards.pl:1229:
# Warning:    Redefined static procedure illegal_column_data/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:1011
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_recognise.pl:99:
# Warning:    Redefined static procedure all_ogs/3
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:814
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_recognise.pl:815:
# Warning:    Redefined static procedure pre_ogs_alter/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:826
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_recognise.pl:833:
# Warning:    Redefined static procedure rot_ogs/1
# Warning:    Previously defined at /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_boards_dpg.pl:833
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_grid_size.pl:28:
# Warning:    Singleton variables: [ProofM]
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_grid_size.pl:89:
# Warning:    Singleton variables: [X,Y,OX,OY]
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_grid_size.pl:89:
# Warning:    Singleton variable in branch: X
# Warning:    Singleton variable in branch: Y
# Warning:    Singleton variable in branch: OX
# Warning:    Singleton variable in branch: OY
# show_time_gt_duration(0.8153753280639648>0.3,create_points_plus_now)
# maybe_report_time(0.8153753280639648>0.3,create_points_plus_now)
# %~ 'removed check:list_undefined and list_void_declarations use:  ?- real_list_undefined([]),real_list_void_declarations. '.
# Warning: /opt/logicmoo_workspace/packs_sys/logicmoo_agi/prolog/kaggle_arc_new/kaggle_arc_prior_groups.pl:1570:
# Warning:    Singleton variables: [N1,IL]
# %~ files('../shared/data/training/*.json')=402.
# %~ files('../shared/data/devaluation/*.json')=400.
# %~ files('../shared/data/1D_testset/*')=12.
# %~ files('../ARC-Others/dbigham/Data/MyTrainingData/*')=21.
# %~ files('../shared/data/ConceptARC/corpus/AboveBelow/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/Center/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/CleanUp/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/CleanUp/OriginalARCEvalSet/*')=1.
# %~ files('../shared/data/ConceptARC/corpus/CompleteShape/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/Copy/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/Copy/OriginalARCEvalSet/*')=2.
# %~ files('../shared/data/ConceptARC/corpus/Count/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/Count/OriginalARCEvalSet/*')=6.
# %~ files('../shared/data/ConceptARC/corpus/ExtendToBoundary/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/ExtendToBoundary/OriginalARCEvalSet/*')=2.
# %~ files('../shared/data/ConceptARC/corpus/ExtractObjects/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/ExtractObjects/OriginalARCEvalSet/*')=2.
# %~ files('../shared/data/ConceptARC/corpus/FilledNotFilled/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/FilledNotFilled/OriginalARCEvalSet/*')=1.
# %~ files('../shared/data/ConceptARC/corpus/HorizontalVertical/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/HorizontalVertical/OriginalARCEvalSet/*')=1.
# %~ files('../shared/data/ConceptARC/corpus/InsideOutside/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/MoveToBoundary/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/MoveToBoundary/OriginalARCEvalSet/*')=4.
# %~ files('../shared/data/ConceptARC/corpus/Order/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/Order/OriginalARCEvalSet/*')=2.
# %~ files('../shared/data/ConceptARC/corpus/ProblemsWithErrors/*')=1.
# %~ files('../shared/data/ConceptARC/corpus/ProblemsWithErrors/Fixed/*')=4.
# %~ skipping_file('../shared/data/ConceptARC/corpus/ProblemsWithErrors/FixedARCProblems.zip')
# %~ files('../shared/data/ConceptARC/corpus/ProblemsWithErrors/Original/*')=4.
# %~ files('../shared/data/ConceptARC/corpus/SameDifferent/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/SameDifferent/OriginalARCEvalSet/*')=5.
# %~ files('../shared/data/ConceptARC/corpus/TopBottom2D/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/TopBottom3D/*')=11.
# %~ files('../shared/data/ConceptARC/corpus/TopBottom3D/OriginalARCEvalSet/*')=1.
# %~ files('../ARC-Others/MINI-ARC/data/MiniARC/*.json')=149.
# %~ files('./secret_data/evaluation/*.json')=100.
# switched((evaluation-->test_names_by_fav))
# recreating(test_names_ord_favs)
# done_recreating(test_names_ord_favs)
# start(gen_gids)
# end(gen_gids)
#
# switched((test_names_by_fav-->dmiles_nsn))
# switched((dmiles_nsn-->dmiles_fast))
# switched((dmiles_fast-->dmiles_cc_1))
# switched((dmiles_cc_1-->dmiles_lr))
# switched((dmiles_lr-->dmiles))
# switched((dmiles-->dmiles_all))
# %~ main_file.
# get_current_test(v(e41c6fd3))0=black[.] 1=blue[©] 2=red[®] 3=green[G] 4=yellow[Y] 5=silver[s] 6=purple[v] 7=orange[o] 8=cyan[½] 9=brown[B] zero=zero[f] fg=fg[*] wfg=wfg[.] bg= [,] wbg=wbg[q] black=black[.] #101010=#101010[#101010] #100010=#100010[#100010] #104010=#104010[#104010] #4a2a2a=#4a2a2a[#4a2a2a]
#    _________________________________________
#   | . @ @ @ @ @ @ @ @ @ @ @ @     . @ @   @ |
#   | @   @ @ .     @ @ @ @ @ @ @ @ @ @ @ @ . |
#   | . @ @ @ @ @ @ @ @ @ @ @ @     . @ @   @ |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# synthesized(user:show_reduced_outputs)
# synthesized(user:compute_all_test_hints)
# synthesized(user:print_reduced_io)
# synthesized(user:show_object_dependancy)
# synthesized(user:test_predict_grid_size)
# synthesized(user:ensure_propcounts)
# synthesized(user:learn_grid_size)
# synthesized(user:show_groups)
# synthesized(user:show_all_test_reductions)
# synthesized(user:show_reduced_pairs)
# synthesized(user:detect_pair_hints)
# synthesized(user:print_individuals2)
# synthesized(user:show_reduced_io)
# synthesized(user:print_scene_change_rules)
# synthesized(user:ensure_individuals1)
# synthesized(user:show_filtered_groups)
# synthesized(user:test_abstracted_recall)
# synthesized(user:compute_and_show_test_hints)
# synthesized(user:clear_object_dependancy)
# synthesized(user:show_reduced_io_fav)
# synthesized(user:print_best_individuals)
# synthesized(user:deduce_shapes)
# synthesized(user:cache_grid_objs)
# synthesized(user:print_hybrid_set)
# synthesized(user:test_example_grid)
# synthesized(user:test_show_grid_objs)
# synthesized(user:compile_and_save_hints_now)
# synthesized(user:show_pair_groups)
# synthesized(user:show_reduced_inputs)
# synthesized(user:ensure_scene_change_rules)
# synthesized(user:compute_scene_change)
# synthesized(user:learn_ilp)
# synthesized(user:show_assumed_mapped)
# synthesized(user:print_individuals)
# % 102,902 inferences, 0.016 CPU in 0.016 seconds (100% CPU, 6243031 Lips)
# start(gen_gids)
# end(gen_gids)
# %~ main_file_complete.
# 0=black[.] 1=blue[©] 2=red[®] 3=green[G] 4=yellow[Y] 5=silver[s] 6=purple[v] 7=orange[o] 8=cyan[½] 9=brown[B] zero=zero[f] fg=fg[*] wfg=wfg[.] bg= [,] wbg=wbg[q] black=black[.] #101010=#101010[#101010] #100010=#100010[#100010] #104010=#104010[#104010] #4a2a2a=#4a2a2a[#4a2a2a]
#    _________________________________________
#   | . @ @ @ @ @ @ @ @ @ @ @ @     . @ @   @ |
#   | @   @ @ .     @ @ @ @ @ @ @ @ @ @ @ @ . |
#   | . @ @ @ @ @ @ @ @ @ @ @ @     . @ @   @ |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
#
# % Type ?-
#   load_from_main   ,
#   catch_log(load_json_files)      ,
#   catch_log(load_task_states)     ,
#   catch_log(devaluation)          ,
#   catch_log(gen_gids)             ,
#   catch_log(create_group_dmiles)  ,
#   catch_log(test_show_colors)     ,
#   demo. % or press up arrow

# %%
for soln in prolog.query("print_test"): print()
# Out:
# % =========================================================================================================================
# %main % ?- print_test(v(e41c6fd3)).
# % =========================================================================================================================
# /*
# hard= -128
# */
# %
#  _________________________________________________________________________________
# testcase(v(e41c6fd3)>trn+0,"
#    _______________________________________________       _______________________________________________
#   | . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . @ @ . . . . . . . . . . |     | . . . . @ @ . . . . . @ @ . . . . @ @ . . . . |
#   | . . . . . . . . . . @ @ @ @ . . . . . . . . . |     | . . . @ @ @ @ . . . @ @ @ @ . . @ @ @ @ . . . |
#   | . . . . @ @ . . . . @ @ @ @ . . . . . . . . . |     | . . . @ @ @ @ . . . @ @ @ @ . . @ @ @ @ . . . |
#   | . . . @ @ @ @ . . . @ @ @ @ . . . . . . . . . |     | . . . @ @ @ @ . . . @ @ @ @ . . @ @ @ @ . . . |
#   | . . . @ @ @ @ . . . @ . . @ . . . . . . . . . |     | . . . @ . . @ . . . @ . . @ . . @ . . @ . . . |
#   | . . . @ @ @ @ . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . @ . . @ . . . . . . . . . . @ @ . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . @ @ @ @ . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . @ @ @ @ . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . @ @ @ @ . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . @ . . @ . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯       ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# 	Training Pair #1  "e41c6fd3"  (grid(23,13))		'Output' (grid(23,13))
# ").
#
# testcase(v(e41c6fd3)>trn+1,"
# %~ cant_tell_what_outShouldBe.
# %~ cant_tell_what_outShouldBe.
# %~ cant_tell_what_outShouldBe.
# %~ cant_tell_what_outShouldBe.
#    _____________________________________________________________       _____________________________________________________________
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . @ @ . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . @ . @ @ . @ . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . @ @ @ @ @ @ . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . @ @ . . @ @ . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . @ @ . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . @ @ . . . . . . @ @ . . . . @ @ . . . . @ @ . . |
#   | . . . . @ . @ @ . @ . . . . . . . . . . . . . . . . . . . . |     | . . . . @ . @ @ . @ . . @ . @ @ . @ @ . @ @ . @ @ . @ @ . @ |
#   | . . . . @ @ @ @ @ @ . . . . . . . . . . . . . . . . @ @ . . |     | . . . . @ @ @ @ @ @ . . @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ |
#   | . . . . @ @ . . @ @ . . . . . . . . . . . . . . @ . @ @ . @ |     | . . . . @ @ . . @ @ . . @ @ . . @ @ @ @ . . @ @ @ @ . . @ @ |
#   | . . . . . . . . . . . . . . @ @ . . . . . . . . @ @ @ @ @ @ |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . @ . @ @ . @ . . . . . . @ @ . . @ @ |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . @ @ @ @ @ @ . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . @ @ . . @ @ . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯       ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# 	Training Pair #2  "e41c6fd3"  (grid(30,14))		'Output' (grid(30,14))
# ").
#
# testcase(v(e41c6fd3)>trn+2,"
#    _____________________________________________________________       _____________________________________________________________
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . @ @ . . . . . . . . . . . . . . |     | . . . @ @ . . . @ @ . . . . @ @ . . @ @ . . . . . @ @ . . . |
#   | . . . . . . . . . . . . . @ @ @ @ . . . . . . . . @ @ . . . |     | . . @ @ @ @ . @ @ @ @ . . @ @ @ @ @ @ @ @ . . . @ @ @ @ . . |
#   | . . . . . . . . . . . . . . @ @ . . . . . . . . @ @ @ @ . . |     | . . . @ @ . . . @ @ . . . . @ @ . . @ @ . . . . . @ @ . . . |
#   | . . . @ @ . . . . . . . . @ @ @ @ . . . . . . . . @ @ . . . |     | . . @ @ @ @ . @ @ @ @ . . @ @ @ @ @ @ @ @ . . . @ @ @ @ . . |
#   | . . @ @ @ @ . . . . . . . . . . . . . . . . . . @ @ @ @ . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . @ @ . . . . . . . . . . . . . @ @ . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . @ @ @ @ . . @ @ . . . . . . . @ @ @ @ . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . @ @ @ @ . . . . . . . @ @ . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . @ @ . . . . . . . @ @ @ @ . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . @ @ @ @ . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯       ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# 	Training Pair #3  "e41c6fd3"  (grid(30,16))		'Output' (grid(30,16))
# ").
#
# testcase(v(e41c6fd3)>tst+0,"
# %~ cant_tell_what_outShouldBe.
# %~ cant_tell_what_outShouldBe.
#    _____________________________________________________________       _____________________________________________________________
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . @ @ @ @ @ . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . @ . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . @ @ @ . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . @ @ @ @ @ . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . @ . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . @ @ @ @ @ . . . . |     | . . @ @ @ @ @ . . @ @ @ @ @ @ @ @ @ @ . . @ @ @ @ @ . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . @ . . . . . . |     | . . . . @ . . . . . . @ . . . . @ . . . . . . @ . . . . . . |
#   | . . @ @ @ @ @ . . . . . . . . . . . . . . . @ @ @ . . . . . |     | . . . @ @ @ . . . . @ @ @ . . @ @ @ . . . . @ @ @ . . . . . |
#   | . . . . @ . . . . . . . . . . . . . . . . @ @ @ @ @ . . . . |     | . . @ @ @ @ @ . . @ @ @ @ @ @ @ @ @ @ . . @ @ @ @ @ . . . . |
#   | . . . @ @ @ . . . . . . . . . . . . . . . . . @ . . . . . . |     | . . . . @ . . . . . . @ . . . . @ . . . . . . @ . . . . . . |
#   | . . @ @ @ @ @ . . @ @ @ @ @ . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . @ . . . . . . @ . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . @ @ @ . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . @ @ @ @ @ . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . @ . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯       ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# 	EVALUATION TEST #1  "e41c6fd3"  (grid(30,17))		'Output<(REVEALED)>' (grid(30,17))
# ").
#
# %= fav(v(e41c6fd3),[no_sol(i(complete),copy_grid(in),incomplete),solves([run_dsl(12,[f(fgpartition,in,_64324),f(matcher,color,'EIGHT',_64340),f(extract,_64324,_64340,_64356),f(remove,_64356,_64324,_64372),f(uppermost,_64356,_64386),f(merge,_64372,_64400),f(cover,in,_64400,_64416),f(lbind,subtract,_64386,_64432),f(chain,toivec,_64432,uppermost,_64450),f(fork,shift,identity,_64450,_64468),f(mapply,_64468,_64372,_64484),f(paint,_64416,_64484,out)])]),ohuman([forall((iz(_64200,outl),color(_64200,cyan),vert_pos(_64200,_64220)),(iz(_64230,outl),vert_pos(_64230,_64220)))]),loadmask(['../shared/data/devaluation/*.json']),indiv_h([colormass]),filename(['../shared/data/devaluation/e41c6fd3.json']),dsl_length([12]),-rotation_match,-mask_match,+shape_match,+color_match,'shared-devaluation',grid_size_same,eval400,alphabetical_v,'(3, 1) ']).
# %~ cant_tell_what_outShouldBe.
# %~ cant_tell_what_outShouldBe.

# %%
for soln in prolog.query("solve_via_scene_change"): print()
# Out:
# cc
# %~ user: message_hook(
# %~          error(existence_error(procedure,send/2),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[send/2]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_pl.pl:37:
# ERROR:    Unknown procedure: send/2
# %~ user: message_hook(
# %~          error(existence_error(procedure,get/3),Existence_error),
# %~          error,
# %~          [ 'Unknown procedure: ~q'-[get/3], nl,'  However, there are definitions for:',nl,
# %~            '        ~q'-[det/1],nl,
# %~            '        ~q'-[get/1],nl,
# %~            '        ~q'-[get0/1],nl,
# %~            '        ~q'-[get/2],nl,
# %~            '        ~q'-[get0/2],nl]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_pl.pl:37:
# ERROR:    Unknown procedure: get/3
# ERROR:      However, there are definitions for:
# ERROR:            det/1
# ERROR:            get/1
# ERROR:            get0/1
# ERROR:            get/2
# ERROR:            get0/2
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_error/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_error/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_expansion.pl:43:
# ERROR:    Unknown procedure: pce_error/1
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_info/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_info/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_expansion.pl:43:
# ERROR:    Unknown procedure: pce_info/1
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_warn/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_warn/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_expansion.pl:43:
# ERROR:    Unknown procedure: pce_warn/1
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_error/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_error/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_realise.pl:46:
# ERROR:    Unknown procedure: pce_error/1
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_error/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_error/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_goal_expansion.pl:39:
# ERROR:    Unknown procedure: pce_error/1
# %~ user: message_hook(
# %~          error(existence_error(procedure,get/3),Existence_error),
# %~          error,
# %~          [ 'Unknown procedure: ~q'-[get/3], nl,'  However, there are definitions for:',nl,
# %~            '        ~q'-[det/1],nl,
# %~            '        ~q'-[get/1],nl,
# %~            '        ~q'-[get0/1],nl,
# %~            '        ~q'-[get/2],nl,
# %~            '        ~q'-[get0/2],nl]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/lib/english/pce_messages.pl:40:
# ERROR:    Unknown procedure: get/3
# ERROR:      However, there are definitions for:
# ERROR:            det/1
# ERROR:            get/1
# ERROR:            get0/1
# ERROR:            get/2
# ERROR:            get0/2
# %~ user: message_hook(
# %~          error(existence_error(procedure,send/2),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[send/2]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_pl.pl:37:
# ERROR:    Unknown procedure: send/2
# %~ user: message_hook(
# %~          error(existence_error(procedure,get/3),Existence_error),
# %~          error,
# %~          [ 'Unknown procedure: ~q'-[get/3], nl,'  However, there are definitions for:',nl,
# %~            '        ~q'-[det/1],nl,
# %~            '        ~q'-[get/1],nl,
# %~            '        ~q'-[get0/1],nl,
# %~            '        ~q'-[get/2],nl,
# %~            '        ~q'-[get0/2],nl]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_pl.pl:37:
# ERROR:    Unknown procedure: get/3
# ERROR:      However, there are definitions for:
# ERROR:            det/1
# ERROR:            get/1
# ERROR:            get0/1
# ERROR:            get/2
# ERROR:            get0/2
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_error/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_error/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_expansion.pl:43:
# ERROR:    Unknown procedure: pce_error/1
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_info/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_info/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_expansion.pl:43:
# ERROR:    Unknown procedure: pce_info/1
# %~ /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_expansion.pl:43
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_warn/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_warn/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_expansion.pl:43:
# ERROR:    Unknown procedure: pce_warn/1
# %~ /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_realise.pl:46
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_error/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_error/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_realise.pl:46:
# ERROR:    Unknown procedure: pce_error/1
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_error/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_error/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_goal_expansion.pl:39:
# ERROR:    Unknown procedure: pce_error/1
# %~ user: message_hook(
# %~          error(existence_error(procedure,get/3),Existence_error),
# %~          error,
# %~          [ 'Unknown procedure: ~q'-[get/3], nl,'  However, there are definitions for:',nl,
# %~            '        ~q'-[det/1],nl,
# %~            '        ~q'-[get/1],nl,
# %~            '        ~q'-[get0/1],nl,
# %~            '        ~q'-[get/2],nl,
# %~            '        ~q'-[get0/2],nl]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/lib/english/pce_messages.pl:40:
# ERROR:    Unknown procedure: get/3
# ERROR:      However, there are definitions for:
# ERROR:            det/1
# ERROR:            get/1
# ERROR:            get0/1
# ERROR:            get/2
# ERROR:            get0/2
# %~ /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_pl.pl:37
# %~ user: message_hook(
# %~          error(existence_error(procedure,send/2),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[send/2]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_pl.pl:37:
# ERROR:    Unknown procedure: send/2
# %~ user: message_hook(
# %~          error(existence_error(procedure,get/3),Existence_error),
# %~          error,
# %~          [ 'Unknown procedure: ~q'-[get/3], nl,'  However, there are definitions for:',nl,
# %~            '        ~q'-[det/1],nl,
# %~            '        ~q'-[get/1],nl,
# %~            '        ~q'-[get0/1],nl,
# %~            '        ~q'-[get/2],nl,
# %~            '        ~q'-[get0/2],nl]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_pl.pl:37:
# ERROR:    Unknown procedure: get/3
# ERROR:      However, there are definitions for:
# ERROR:            det/1
# ERROR:            get/1
# ERROR:            get0/1
# ERROR:            get/2
# ERROR:            get0/2
# %~ /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_expansion.pl:43
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_error/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_error/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_expansion.pl:43:
# ERROR:    Unknown procedure: pce_error/1
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_info/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_info/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_expansion.pl:43:
# ERROR:    Unknown procedure: pce_info/1
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_warn/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_warn/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_expansion.pl:43:
# ERROR:    Unknown procedure: pce_warn/1
# %~ /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_realise.pl:46
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_error/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_error/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_realise.pl:46:
# ERROR:    Unknown procedure: pce_error/1
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_error/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_error/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_goal_expansion.pl:39:
# ERROR:    Unknown procedure: pce_error/1
# %~ /opt/logicmoo_workspace/lib/swipl/xpce/prolog/lib/english/pce_messages.pl:40
# %~ user: message_hook(
# %~          error(existence_error(procedure,get/3),Existence_error),
# %~          error,
# %~          [ 'Unknown procedure: ~q'-[get/3], nl,'  However, there are definitions for:',nl,
# %~            '        ~q'-[det/1],nl,
# %~            '        ~q'-[get/1],nl,
# %~            '        ~q'-[get0/1],nl,
# %~            '        ~q'-[get/2],nl,
# %~            '        ~q'-[get0/2],nl]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/lib/english/pce_messages.pl:40:
# ERROR:    Unknown procedure: get/3
# ERROR:      However, there are definitions for:
# ERROR:            det/1
# ERROR:            get/1
# ERROR:            get0/1
# ERROR:            get/2
# ERROR:            get0/2
# %~ user: message_hook(
# %~          error(existence_error(procedure,send/2),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[send/2]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_pl.pl:37:
# ERROR:    Unknown procedure: send/2
# %~ user: message_hook(
# %~          error(existence_error(procedure,get/3),Existence_error),
# %~          error,
# %~          [ 'Unknown procedure: ~q'-[get/3], nl,'  However, there are definitions for:',nl,
# %~            '        ~q'-[det/1],nl,
# %~            '        ~q'-[get/1],nl,
# %~            '        ~q'-[get0/1],nl,
# %~            '        ~q'-[get/2],nl,
# %~            '        ~q'-[get0/2],nl]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_pl.pl:37:
# ERROR:    Unknown procedure: get/3
# ERROR:      However, there are definitions for:
# ERROR:            det/1
# ERROR:            get/1
# ERROR:            get0/1
# ERROR:            get/2
# ERROR:            get0/2
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_error/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_error/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_expansion.pl:43:
# ERROR:    Unknown procedure: pce_error/1
# %~ /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_expansion.pl:43
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_info/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_info/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_expansion.pl:43:
# ERROR:    Unknown procedure: pce_info/1
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_warn/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_warn/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_expansion.pl:43:
# ERROR:    Unknown procedure: pce_warn/1
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_error/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_error/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_realise.pl:46:
# ERROR:    Unknown procedure: pce_error/1
# %~ user: message_hook(
# %~          error(existence_error(procedure,pce_error/1),Existence_error),
# %~          error,
# %~          ['Unknown procedure: ~q'-[pce_error/1]]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/boot/pce_goal_expansion.pl:39:
# ERROR:    Unknown procedure: pce_error/1
# %~ /opt/logicmoo_workspace/lib/swipl/xpce/prolog/lib/english/pce_messages.pl:40
# %~ user: message_hook(
# %~          error(existence_error(procedure,get/3),Existence_error),
# %~          error,
# %~          [ 'Unknown procedure: ~q'-[get/3], nl,'  However, there are definitions for:',nl,
# %~            '        ~q'-[det/1],nl,
# %~            '        ~q'-[get/1],nl,
# %~            '        ~q'-[get0/1],nl,
# %~            '        ~q'-[get/2],nl,
# %~            '        ~q'-[get0/2],nl]).
# ERROR: /opt/logicmoo_workspace/lib/swipl/xpce/prolog/lib/english/pce_messages.pl:40:
# ERROR:    Unknown procedure: get/3
# ERROR:      However, there are definitions for:
# ERROR:            det/1
# ERROR:            get/1
# ERROR:            get0/1
# ERROR:            get/2
# ERROR:            get0/2
# % =========================================================================================================================
# %main % ?- print_test(v(e41c6fd3)).
# % =========================================================================================================================
# /*
# hard= -128
# */
# %
#  _________________________________________________________________________________
# testcase(v(e41c6fd3)>trn+0,"
#    _______________________________________________       _______________________________________________
#   | . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . @ @ . . . . . . . . . . |     | . . . . @ @ . . . . . @ @ . . . . @ @ . . . . |
#   | . . . . . . . . . . @ @ @ @ . . . . . . . . . |     | . . . @ @ @ @ . . . @ @ @ @ . . @ @ @ @ . . . |
#   | . . . . @ @ . . . . @ @ @ @ . . . . . . . . . |     | . . . @ @ @ @ . . . @ @ @ @ . . @ @ @ @ . . . |
#   | . . . @ @ @ @ . . . @ @ @ @ . . . . . . . . . |     | . . . @ @ @ @ . . . @ @ @ @ . . @ @ @ @ . . . |
#   | . . . @ @ @ @ . . . @ . . @ . . . . . . . . . |     | . . . @ . . @ . . . @ . . @ . . @ . . @ . . . |
#   | . . . @ @ @ @ . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . @ . . @ . . . . . . . . . . @ @ . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . @ @ @ @ . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . @ @ @ @ . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . @ @ @ @ . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . @ . . @ . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯       ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# 	Training Pair #1  "e41c6fd3"  (grid(23,13))		'Output' (grid(23,13))
# ").
#
# testcase(v(e41c6fd3)>trn+1,"
# %~ cant_tell_what_outShouldBe.
# %~ cant_tell_what_outShouldBe.
# %~ cant_tell_what_outShouldBe.
# %~ cant_tell_what_outShouldBe.
#    _____________________________________________________________       _____________________________________________________________
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . @ @ . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . @ . @ @ . @ . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . @ @ @ @ @ @ . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . @ @ . . @ @ . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . @ @ . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . @ @ . . . . . . @ @ . . . . @ @ . . . . @ @ . . |
#   | . . . . @ . @ @ . @ . . . . . . . . . . . . . . . . . . . . |     | . . . . @ . @ @ . @ . . @ . @ @ . @ @ . @ @ . @ @ . @ @ . @ |
#   | . . . . @ @ @ @ @ @ . . . . . . . . . . . . . . . . @ @ . . |     | . . . . @ @ @ @ @ @ . . @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ |
#   | . . . . @ @ . . @ @ . . . . . . . . . . . . . . @ . @ @ . @ |     | . . . . @ @ . . @ @ . . @ @ . . @ @ @ @ . . @ @ @ @ . . @ @ |
#   | . . . . . . . . . . . . . . @ @ . . . . . . . . @ @ @ @ @ @ |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . @ . @ @ . @ . . . . . . @ @ . . @ @ |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . @ @ @ @ @ @ . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . @ @ . . @ @ . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯       ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# 	Training Pair #2  "e41c6fd3"  (grid(30,14))		'Output' (grid(30,14))
# ").
#
# testcase(v(e41c6fd3)>trn+2,"
#    _____________________________________________________________       _____________________________________________________________
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . @ @ . . . . . . . . . . . . . . |     | . . . @ @ . . . @ @ . . . . @ @ . . @ @ . . . . . @ @ . . . |
#   | . . . . . . . . . . . . . @ @ @ @ . . . . . . . . @ @ . . . |     | . . @ @ @ @ . @ @ @ @ . . @ @ @ @ @ @ @ @ . . . @ @ @ @ . . |
#   | . . . . . . . . . . . . . . @ @ . . . . . . . . @ @ @ @ . . |     | . . . @ @ . . . @ @ . . . . @ @ . . @ @ . . . . . @ @ . . . |
#   | . . . @ @ . . . . . . . . @ @ @ @ . . . . . . . . @ @ . . . |     | . . @ @ @ @ . @ @ @ @ . . @ @ @ @ @ @ @ @ . . . @ @ @ @ . . |
#   | . . @ @ @ @ . . . . . . . . . . . . . . . . . . @ @ @ @ . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . @ @ . . . . . . . . . . . . . @ @ . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . @ @ @ @ . . @ @ . . . . . . . @ @ @ @ . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . @ @ @ @ . . . . . . . @ @ . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . @ @ . . . . . . . @ @ @ @ . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . @ @ @ @ . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯       ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# 	Training Pair #3  "e41c6fd3"  (grid(30,16))		'Output' (grid(30,16))
# ").
#
# testcase(v(e41c6fd3)>tst+0,"
# %~ cant_tell_what_outShouldBe.
# %~ cant_tell_what_outShouldBe.
# %~ cant_tell_what_outShouldBe.
# %~ cant_tell_what_outShouldBe.
#    _____________________________________________________________       _____________________________________________________________
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . @ @ @ @ @ . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . @ . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . @ @ @ . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . @ @ @ @ @ . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . @ . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . @ @ @ @ @ . . . . |     | . . @ @ @ @ @ . . @ @ @ @ @ @ @ @ @ @ . . @ @ @ @ @ . . . . |
#   | . . . . . . . . . . . . . . . . . . . . . . . @ . . . . . . |     | . . . . @ . . . . . . @ . . . . @ . . . . . . @ . . . . . . |
#   | . . @ @ @ @ @ . . . . . . . . . . . . . . . @ @ @ . . . . . |     | . . . @ @ @ . . . . @ @ @ . . @ @ @ . . . . @ @ @ . . . . . |
#   | . . . . @ . . . . . . . . . . . . . . . . @ @ @ @ @ . . . . |     | . . @ @ @ @ @ . . @ @ @ @ @ @ @ @ @ @ . . @ @ @ @ @ . . . . |
#   | . . . @ @ @ . . . . . . . . . . . . . . . . . @ . . . . . . |     | . . . . @ . . . . . . @ . . . . @ . . . . . . @ . . . . . . |
#   | . . @ @ @ @ @ . . @ @ @ @ @ . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . @ . . . . . . @ . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . @ @ @ . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . @ @ @ @ @ . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#   | . . . . . . . . . . . @ . . . . . . . . . . . . . . . . . . |     | . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯       ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# 	EVALUATION TEST #1  "e41c6fd3"  (grid(30,17))		'Output<(REVEALED)>' (grid(30,17))
# ").
#
# %= fav(v(e41c6fd3),[no_sol(i(complete),copy_grid(in),incomplete),solves([run_dsl(12,[f(fgpartition,in,_61974),f(matcher,color,'EIGHT',_61990),f(extract,_61974,_61990,_62006),f(remove,_62006,_61974,_62022),f(uppermost,_62006,_62036),f(merge,_62022,_62050),f(cover,in,_62050,_62066),f(lbind,subtract,_62036,_62082),f(chain,toivec,_62082,uppermost,_62100),f(fork,shift,identity,_62100,_62118),f(mapply,_62118,_62022,_62134),f(paint,_62066,_62134,out)])]),ohuman([forall((iz(_61850,outl),color(_61850,cyan),vert_pos(_61850,_61870)),(iz(_61880,outl),vert_pos(_61880,_61870)))]),loadmask(['../shared/data/devaluation/*.json']),indiv_h([colormass]),filename(['../shared/data/devaluation/e41c6fd3.json']),dsl_length([12]),-rotation_match,-mask_match,+shape_match,+color_match,'shared-devaluation',grid_size_same,eval400,alphabetical_v,'(3, 1) ']).
#  _________________________________________________________________________________
# %~ best_obj_group_pair=howIO(HowIO).
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+0)*(in),v_e41c6fd3_trn_0_in))
#  _________________________________________________________________________________
# !individuate8(_160376,v(e41c6fd! "individuate([ do_im_complete, maybe_lo_dots,remove_illegals, \n              remove_used_points,...],v(e41c6fd3)>(trn+0)*in)" |
#    recreating(test_info)
#     % Success 100% (570/570) for report_count(progress,so_far) in 7.011904001235962 seconds
#     % Success 100% (1148/1148) for report_count(progress,so_far) in 14.013161659240723 seconds
#     % Success 100% (1187/1187) for report_count(all_arc_test_name_unordered(_69206),test_info_recache(_69206,_69212))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+0)*(in),v_e41c6fd3_trn_0_in))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+0)*(in),v_e41c6fd3_trn_0_in))
#  in 14.497806310653687 seconds
#
# ¡individuate8(_160376,v(e41c6fd¡
#  _________________________________________________________________________________
# !individuate8(_221958,v(e41c6fd! "individuate([ simple(i_opts(shapes(none),count_equ(Equ),colors(each),dirs(nsew),incl_bg(false))), \n              ...],v(e41c6fd3)>(trn+0)*in)" |
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+0)*(in),v_e41c6fd3_trn_0_in))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+0)*(in),v_e41c6fd3_trn_0_in))
# ¡individuate8(_221958,v(e41c6fd¡
#  _________________________________________________________________________________
# !individuate8(_369474,v(e41c6fd! "individuate([ do_im_complete, maybe_lo_dots,remove_illegals, \n              remove_used_points,...],v(e41c6fd3)>(trn+0)*out)" |
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+0)*out,v_e41c6fd3_trn_0_out))
#    ¡individuate8(_369474,v(e41c6fd¡
#  _________________________________________________________________________________
# !individuate8(_157806,v(e41c6fd! "individuate([ simple(i_opts(shapes(none),count_equ(Equ),colors(each),dirs(nsew),incl_bg(false))), \n              ...],v(e41c6fd3)>(trn+0)*out)" |
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+0)*out,v_e41c6fd3_trn_0_out))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+0)*out,v_e41c6fd3_trn_0_out))
#    ¡individuate8(_157806,v(e41c6fd¡
#  _________________________________________________________________________________
#    _______________________________________________       _______________________________________________
#   |                                               |     |                                               |
#   |                       Ꮦ Ꮦ                     |     |         ሇ ሇ           Ꮦ Ꮦ         ƾ ƾ         |
#   |                     Ꮦ Ꮦ Ꮦ Ꮦ                   |     |       ሇ ሇ ሇ ሇ       Ꮦ Ꮦ Ꮦ Ꮦ     ƾ ƾ ƾ ƾ       |
#   |         Ꮕ Ꮕ         Ꮦ Ꮦ Ꮦ Ꮦ                   |     |       ሇ ሇ ሇ ሇ       Ꮦ Ꮦ Ꮦ Ꮦ     ƾ ƾ ƾ ƾ       |
#   |       Ꮕ Ꮕ Ꮕ Ꮕ       Ꮦ Ꮦ Ꮦ Ꮦ                   |     |       ሇ ሇ ሇ ሇ       Ꮦ Ꮦ Ꮦ Ꮦ     ƾ ƾ ƾ ƾ       |
#   |       Ꮕ Ꮕ Ꮕ Ꮕ       Ꮦ     Ꮦ                   |     |       ሇ     ሇ       Ꮦ     Ꮦ     ƾ     ƾ       |
#   |       Ꮕ Ꮕ Ꮕ Ꮕ                                 |     |                                               |
#   |       Ꮕ     Ꮕ                     а а         |     |                                               |
#   |                                 а а а а       |     |                                               |
#   |                                 а а а а       |     |                                               |
#   |                                 а а а а       |     |                                               |
#   |                                 а     а       |     |                                               |
#   |                                               |     |                                               |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯       ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# 	"v(e41c6fd3)>(trn+0)*ci_co(3,3)"  (group(3))		 (group(3))
#
#        in_out(i_opts(shapes(none),count_equ(_66522),colors(each),dirs(nsew),incl_bg(false)),i_opts(shapes(none),count_equ(_95902),colors(each),dirs(nsew),incl_bg(false)))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+0)*out,v_e41c6fd3_trn_0_out))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+0)*out,v_e41c6fd3_trn_0_out))
# %~ duplicated(_54454)
# %~ duplicated(_54454)
# %~ duplicated(_54454)
# %~ duplicated(_54454)
# %~ duplicated(_54454)
# %~ duplicated(_54454)
# %~ duplicated(_54454)
# %~ duplicated(_54454)
# %~ best_obj_group_pair=howIO(HowIO).
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+1)*(in),v_e41c6fd3_trn_1_in))
#  _________________________________________________________________________________
# !individuate8(_746290,v(e41c6fd! "individuate([ do_im_complete, maybe_lo_dots,remove_illegals, \n              remove_used_points,...],v(e41c6fd3)>(trn+1)*in)" |
#    ¡individuate8(_746290,v(e41c6fd¡
#  _________________________________________________________________________________
# !individuate8(_147580,v(e41c6fd! "individuate([ simple(i_opts(shapes(none),count_equ(Equ),colors(each),dirs(nsew),incl_bg(false))), \n              ...],v(e41c6fd3)>(trn+1)*in)" |
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+1)*(in),v_e41c6fd3_trn_1_in))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+1)*(in),v_e41c6fd3_trn_1_in))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+1)*(in),v_e41c6fd3_trn_1_in))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+1)*(in),v_e41c6fd3_trn_1_in))
# ¡individuate8(_147580,v(e41c6fd¡
#  _________________________________________________________________________________
# !individuate8(_643140,v(e41c6fd! "individuate([ do_im_complete, maybe_lo_dots,remove_illegals, \n              remove_used_points,...],v(e41c6fd3)>(trn+1)*out)" |
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+1)*out,v_e41c6fd3_trn_1_out))
#    ¡individuate8(_643140,v(e41c6fd¡
#  _________________________________________________________________________________
# !individuate8(_168286,v(e41c6fd! "individuate([ simple(i_opts(shapes(none),count_equ(Equ),colors(each),dirs(nsew),incl_bg(false))), \n              ...],v(e41c6fd3)>(trn+1)*out)" |
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+1)*out,v_e41c6fd3_trn_1_out))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+1)*out,v_e41c6fd3_trn_1_out))
#    ¡individuate8(_168286,v(e41c6fd¡
#  _________________________________________________________________________________
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+1)*out,v_e41c6fd3_trn_1_out))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+1)*out,v_e41c6fd3_trn_1_out))
#    _____________________________________________________________       _____________________________________________________________
#   |                                                             |     |                                                             |
#   |                                                             |     |                                                             |
#   |                                         ʮ ʮ                 |     |                                                             |
#   |                                     ʮ   ʮ ʮ   ʮ             |     |                                                             |
#   |                                     ʮ ʮ ʮ ʮ ʮ ʮ             |     |                                                             |
#   |                                     ʮ ʮ     ʮ ʮ             |     |                                                             |
#   |             ҕ ҕ                                             |     |             ҕ ҕ             Ᏻ Ᏻ         Ԑ Ԑ         ԡ ԡ     |
#   |         ҕ   ҕ ҕ   ҕ                                         |     |         ҕ   ҕ ҕ   ҕ     Ᏻ   Ᏻ Ᏻ   Ᏻ Ԑ   Ԑ Ԑ   Ԑ ԡ   ԡ ԡ   ԡ |
#   |         ҕ ҕ ҕ ҕ ҕ ҕ                                 Յ Յ     |     |         ҕ ҕ ҕ ҕ ҕ ҕ     Ᏻ Ᏻ Ᏻ Ᏻ Ᏻ Ᏻ Ԑ Ԑ Ԑ Ԑ Ԑ Ԑ ԡ ԡ ԡ ԡ ԡ ԡ |
#   |         ҕ ҕ     ҕ ҕ                             Յ   Յ Յ   Յ |     |         ҕ ҕ     ҕ ҕ     Ᏻ Ᏻ     Ᏻ Ᏻ Ԑ Ԑ     Ԑ Ԑ ԡ ԡ     ԡ ԡ |
#   |                             Ꮶ Ꮶ                 Յ Յ Յ Յ Յ Յ |     |                                                             |
#   |                         Ꮶ   Ꮶ Ꮶ   Ꮶ             Յ Յ     Յ Յ |     |                                                             |
#   |                         Ꮶ Ꮶ Ꮶ Ꮶ Ꮶ Ꮶ                         |     |                                                             |
#   |                         Ꮶ Ꮶ     Ꮶ Ꮶ                         |     |                                                             |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯       ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# 	"v(e41c6fd3)>(trn+1)*ci_co(4,4)"  (group(4))		 (group(4))
#
#        in_out(i_opts(shapes(none),count_equ(_75070),colors(each),dirs(nsew),incl_bg(false)),i_opts(shapes(none),count_equ(_119730),colors(each),dirs(nsew),incl_bg(false)))
# %~ duplicated(_54466)
# %~ duplicated(_54466)
# %~ duplicated(_54466)
# %~ duplicated(_54466)
# %~ duplicated(_54466)
# %~ best_obj_group_pair=howIO(HowIO).
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+2)*(in),v_e41c6fd3_trn_2_in))
#  _________________________________________________________________________________
# !individuate8(_443524,v(e41c6fd! "individuate([ do_im_complete, maybe_lo_dots,remove_illegals, \n              remove_used_points,...],v(e41c6fd3)>(trn+2)*in)" |
#    ¡individuate8(_443524,v(e41c6fd¡
#  _________________________________________________________________________________
# !individuate8(_153068,v(e41c6fd! "individuate([ simple(i_opts(shapes(none),count_equ(Equ),colors(each),dirs(nsew),incl_bg(false))), \n              ...],v(e41c6fd3)>(trn+2)*in)" |
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+2)*(in),v_e41c6fd3_trn_2_in))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+2)*(in),v_e41c6fd3_trn_2_in))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+2)*(in),v_e41c6fd3_trn_2_in))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+2)*(in),v_e41c6fd3_trn_2_in))
# ¡individuate8(_153068,v(e41c6fd¡
#  _________________________________________________________________________________
# !individuate8(_295606,v(e41c6fd! "individuate([ do_im_complete, maybe_lo_dots,remove_illegals, \n              remove_used_points,...],v(e41c6fd3)>(trn+2)*out)" |
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+2)*out,v_e41c6fd3_trn_2_out))
#    ¡individuate8(_295606,v(e41c6fd¡
#  _________________________________________________________________________________
# !individuate8(_181568,v(e41c6fd! "individuate([ simple(i_opts(shapes(none),count_equ(Equ),colors(each),dirs(nsew),incl_bg(false))), \n              ...],v(e41c6fd3)>(trn+2)*out)" |
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+2)*out,v_e41c6fd3_trn_2_out))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+2)*out,v_e41c6fd3_trn_2_out))
#    ¡individuate8(_181568,v(e41c6fd¡
#  _________________________________________________________________________________
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+2)*out,v_e41c6fd3_trn_2_out))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(trn+2)*out,v_e41c6fd3_trn_2_out))
#    _____________________________________________________________       _____________________________________________________________
#   |                                                             |     |                                                             |
#   |                                                             |     |                                                             |
#   |                             ʨ ʨ                             |     |       ϲ ϲ       ሠ ሠ         ʨ ʨ     ህ ህ           ӣ ӣ       |
#   |                           ʨ ʨ ʨ ʨ                 ɸ ɸ       |     |     ϲ ϲ ϲ ϲ   ሠ ሠ ሠ ሠ     ʨ ʨ ʨ ʨ ህ ህ ህ ህ       ӣ ӣ ӣ ӣ     |
#   |                             ʨ ʨ                 ɸ ɸ ɸ ɸ     |     |       ϲ ϲ       ሠ ሠ         ʨ ʨ     ህ ህ           ӣ ӣ       |
#   |       Ҋ Ҋ                 ʨ ʨ ʨ ʨ                 ɸ ɸ       |     |     ϲ ϲ ϲ ϲ   ሠ ሠ ሠ ሠ     ʨ ʨ ʨ ʨ ህ ህ ህ ህ       ӣ ӣ ӣ ӣ     |
#   |     Ҋ Ҋ Ҋ Ҋ                                     ɸ ɸ ɸ ɸ     |     |                                                             |
#   |       Ҋ Ҋ                           ѕ ѕ                     |     |                                                             |
#   |     Ҋ Ҋ Ҋ Ҋ     Ȫ Ȫ               ѕ ѕ ѕ ѕ                   |     |                                                             |
#   |               Ȫ Ȫ Ȫ Ȫ               ѕ ѕ                     |     |                                                             |
#   |                 Ȫ Ȫ               ѕ ѕ ѕ ѕ                   |     |                                                             |
#   |               Ȫ Ȫ Ȫ Ȫ                                       |     |                                                             |
#   |                                                             |     |                                                             |
#   |                                                             |     |                                                             |
#   |                                                             |     |                                                             |
#   |                                                             |     |                                                             |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯       ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# 	"v(e41c6fd3)>(trn+2)*ci_co(5,5)"  (group(5))		 (group(5))
#
#        in_out(i_opts(shapes(none),count_equ(_73982),colors(each),dirs(nsew),incl_bg(false)),i_opts(shapes(none),count_equ(_124132),colors(each),dirs(nsew),incl_bg(false)))
#  _________________________________________________________________________________
# %~ duplicated(_54466)
# %~ duplicated(_54466)
# %~ duplicated(_54466)
# %~ duplicated(_54466)
# %~ duplicated(_54466)
#    _____________________________________________________________       _____________________________________________________________
#   |                                                             |     |                                                             |
#   |                                                             |     |                                                             |
#   |                             ʨ ʨ                             |     |       ϲ ϲ       ሠ ሠ         ʨ ʨ     ህ ህ           ӣ ӣ       |
#   |                           ʨ ʨ ʨ ʨ                 ɸ ɸ       |     |     ϲ ϲ ϲ ϲ   ሠ ሠ ሠ ሠ     ʨ ʨ ʨ ʨ ህ ህ ህ ህ       ӣ ӣ ӣ ӣ     |
#   |                             ʨ ʨ                 ɸ ɸ ɸ ɸ     |     |       ϲ ϲ       ሠ ሠ         ʨ ʨ І І ህ ህ           ӣ ӣ       |
#   |       Ҋ Ҋ                 ʨ ʨ ʨ ʨ                 ɸ ɸ       |     |     ϲ ϲ ϲ ϲ   ሠ ሠ ሠ ሠ     ʨ ʨ ʨ ʨ ህ ህ ህ ህ       ӣ ӣ ӣ ӣ     |
#   |     Ҋ Ҋ Ҋ Ҋ                                     ɸ ɸ ɸ ɸ     |     |                                                             |
#   |       Ҋ Ҋ                           ѕ ѕ                     |     |                                                             |
#   |     Ҋ Ҋ Ҋ Ҋ     Ȫ Ȫ               ѕ ѕ ѕ ѕ                   |     |                                                             |
#   |               Ȫ Ȫ Ȫ Ȫ               ѕ ѕ                     |     |                                                             |
#   |                 Ȫ Ȫ               ѕ ѕ ѕ ѕ                   |     |                                                             |
#   |               Ȫ Ȫ Ȫ Ȫ                                       |     |                                                             |
#   |                                                             |     |                                                             |
#   |                                                             |     |                                                             |
#   |                                                             |     |                                                             |
#   |                                                             |     |                                                             |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯       ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# 	"v(e41c6fd3)>(trn+2)*ci_co(5,6)"  (group(5))		 (group(6))
#
#        in_out(i_opts(shapes(none),count_equ(_73982),colors(each),dirs(nsew),incl_bg(false)),complete)
# %~ duplicated(_54466)
# %~ duplicated(_54466)
# %~ duplicated(_54466)
# %~ duplicated(_54466)
# %~ duplicated(_54466)
# %~ best_obj_group_pair=howIO(HowIO).
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(tst+0)*(in),v_e41c6fd3_tst_0_in))
#  _________________________________________________________________________________
# !individuate8(_980266,v(e41c6fd! "individuate([ do_im_complete, maybe_lo_dots,remove_illegals, \n              remove_used_points,...],v(e41c6fd3)>(tst+0)*in)" |
#    ¡individuate8(_980266,v(e41c6fd¡
#  _________________________________________________________________________________
# !individuate8(_158762,v(e41c6fd! "individuate([ simple(i_opts(shapes(none),count_equ(Equ),colors(each),dirs(nsew),incl_bg(false))), \n              ...],v(e41c6fd3)>(tst+0)*in)" |
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(tst+0)*(in),v_e41c6fd3_tst_0_in))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(tst+0)*(in),v_e41c6fd3_tst_0_in))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(tst+0)*(in),v_e41c6fd3_tst_0_in))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(tst+0)*(in),v_e41c6fd3_tst_0_in))
# ¡individuate8(_158762,v(e41c6fd¡
#  _________________________________________________________________________________
# !individuate8(_872140,v(e41c6fd! "individuate([ do_im_complete, maybe_lo_dots,remove_illegals, \n              remove_used_points,...],v(e41c6fd3)>(tst+0)*out)" |
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(tst+0)*out,v_e41c6fd3_tst_0_out))
#    ¡individuate8(_872140,v(e41c6fd¡
#  _________________________________________________________________________________
# !individuate8(_186264,v(e41c6fd! "individuate([ simple(i_opts(shapes(none),count_equ(Equ),colors(each),dirs(nsew),incl_bg(false))), \n              ...],v(e41c6fd3)>(tst+0)*out)" |
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(tst+0)*out,v_e41c6fd3_tst_0_out))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(tst+0)*out,v_e41c6fd3_tst_0_out))
#    ¡individuate8(_186264,v(e41c6fd¡
#  _________________________________________________________________________________
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(tst+0)*out,v_e41c6fd3_tst_0_out))
# %~ group_prior_objs0_same(tid_gid(v(e41c6fd3)>(tst+0)*out,v_e41c6fd3_tst_0_out))
#    _____________________________________________________________       _____________________________________________________________
#   |                                                             |     |                                                             |
#   |                                                             |     |                                                             |
#   |                             ҫ ҫ ҫ ҫ ҫ                       |     |                                                             |
#   |                                 ҫ                           |     |                                                             |
#   |                               ҫ ҫ ҫ                         |     |                                                             |
#   |                             ҫ ҫ ҫ ҫ ҫ                       |     |                                                             |
#   |                                 ҫ                           |     |                                                             |
#   |                                           Ű Ű Ű Ű Ű         |     |     ል ል ል ል ል     ʠ ʠ ʠ ʠ ʠ Ќ Ќ Ќ Ќ Ќ     Ű Ű Ű Ű Ű         |
#   |                                               Ű             |     |         ል             ʠ         Ќ             Ű             |
#   |     Я Я Я Я Я                               Ű Ű Ű           |     |       ል ል ል         ʠ ʠ ʠ     Ќ Ќ Ќ         Ű Ű Ű           |
#   |         Я                                 Ű Ű Ű Ű Ű         |     |     ል ል ል ል ል     ʠ ʠ ʠ ʠ ʠ Ќ Ќ Ќ Ќ Ќ     Ű Ű Ű Ű Ű         |
#   |       Я Я Я                                   Ű             |     |         ል             ʠ         Ќ             Ű             |
#   |     Я Я Я Я Я     Ꭷ Ꭷ Ꭷ Ꭷ Ꭷ                                 |     |                                                             |
#   |         Я             Ꭷ                                     |     |                                                             |
#   |                     Ꭷ Ꭷ Ꭷ                                   |     |                                                             |
#   |                   Ꭷ Ꭷ Ꭷ Ꭷ Ꭷ                                 |     |                                                             |
#   |                       Ꭷ                                     |     |                                                             |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯       ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# 	"v(e41c6fd3)>(tst+0)*ci_co(4,4)"  (group(4))		 (group(4))
#
#        in_out(i_opts(shapes(none),count_equ(_73104),colors(each),dirs(nsew),incl_bg(false)),i_opts(shapes(none),count_equ(_122894),colors(each),dirs(nsew),incl_bg(false)))
#  _________________________________________________________________________________
# %~ duplicated(_54466)
# %~ duplicated(_54466)
# %~ duplicated(_54466)
# %~ duplicated(_54466)
# %~ duplicated(_54466)
#    _____________________________________________________________       _____________________________________________________________
#   |                                                             |     |                                                             |
#   |                                                             |     |                                                             |
#   |                             ҫ ҫ ҫ ҫ ҫ                       |     |                                                             |
#   |                                 ҫ                           |     |                                                             |
#   |                               ҫ ҫ ҫ                         |     |                                                             |
#   |                             ҫ ҫ ҫ ҫ ҫ                       |     |                                                             |
#   |                                 ҫ                           |     |                                                             |
#   |                                           Ű Ű Ű Ű Ű         |     |     ል ል ል ል ል     ʠ ʠ ʠ ʠ ʠ Ќ Ќ Ќ Ќ Ќ     Ű Ű Ű Ű Ű         |
#   |                                               Ű             |     |         ል             ʠ ƃ ƃ ƃ ƃ Ќ             Ű             |
#   |     Я Я Я Я Я                               Ű Ű Ű           |     |       ል ል ል         ʠ ʠ ʠ ƃ ƃ Ќ Ќ Ќ         Ű Ű Ű           |
#   |         Я                                 Ű Ű Ű Ű Ű         |     |     ል ል ል ል ል     ʠ ʠ ʠ ʠ ʠ Ќ Ќ Ќ Ќ Ќ     Ű Ű Ű Ű Ű         |
#   |       Я Я Я                                   Ű             |     |         ል             ʠ         Ќ             Ű             |
#   |     Я Я Я Я Я     Ꭷ Ꭷ Ꭷ Ꭷ Ꭷ                                 |     |                                                             |
#   |         Я             Ꭷ                                     |     |                                                             |
#   |                     Ꭷ Ꭷ Ꭷ                                   |     |                                                             |
#   |                   Ꭷ Ꭷ Ꭷ Ꭷ Ꭷ                                 |     |                                                             |
# ...
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                             Ᏻ Ᏻ                     ԡ ԡ     |
# 	          	  |                         Ᏻ   Ᏻ Ᏻ   Ᏻ             ԡ   ԡ ԡ   ԡ |
# 	          	  |                         Ᏻ Ᏻ Ᏻ Ᏻ Ᏻ Ᏻ             ԡ ԡ ԡ ԡ ԡ ԡ |
# 	          	  |                         Ᏻ Ᏻ     Ᏻ Ᏻ             ԡ ԡ     ԡ ԡ |
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	   ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
#  _________________________________________________________________________________
#
#    _____________       _____________
#   |     @ @     |     |     @ @     |
#   | @   @ @   @ |     | @   @ @   @ |
#   | @ @ @ @ @ @ |     | @ @ @ @ @ @ |
#   | @ @     @ @ |     | @ @     @ @ |
#    ¯¯¯¯¯¯¯¯¯¯¯¯¯       ¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# 	"copy_object_n_changes(1,inf,3)"  (object)		 (object)
# 	      	diffs =  (1)
# 	               	reposition
# 	      	diffprops =  (1)
# 	               	reposition =
# 	                     	different(iz(locY(_)),iz(locY(7)),iz(locY(9)))
# 	      	sames =  (5)
# 	               	rotate
# 	               	reshape
# 	               	rescale
# 	               	reposition
# 	               	repaint
# 	      	sameprops =  (7)
# 	               	rotate =
# 	                     	same(rot2D(sameR),rot2D(sameR),rot2D(sameR))
# 	               	reshape =
# 	                     	same(iz(algo_sid(norm,s5507379)),iz(algo_sid(norm,s5507379)),iz(algo_sid(norm,s5507379)))
# 	               	reshape =
# 	                     	same(iz(algo_sid(comp,s2083643)),iz(algo_sid(comp,s2083643)),iz(algo_sid(comp,s2083643)))
# 	               	reshape =
# 	                     	same(iz(sid(s7114825)),iz(sid(s7114825)),iz(sid(s7114825)))
# 	               	rescale =
# 	                     	same(mass(16),mass(16),mass(16))
# 	               	reposition =
# 	                     	same(iz(locX(25)),iz(locX(25)),iz(locX(25)))
# 	               	repaint =
# 	                     	same(pen([cc(green,1)]),pen([cc(green,1)]),pen([cc(green,1)]))
#  _________________________________________________________________________________
#
# 	 	new =  (2)
# 	          	rule(
# 	          	   [ diffs_sames(
# 	          	        [ reposition= different(iz(locY(_)),iz(locY(7)),iz(locY(9)))],
# 	          	        [ rotate= same(rot2D(sameR),rot2D(sameR),rot2D(sameR)),
# 	          	          reshape= same(iz(algo_sid(norm,s5507379)),iz(algo_sid(norm,s5507379)),iz(algo_sid(norm,s5507379))),
# 	          	          reshape= same(iz(algo_sid(comp,s2083643)),iz(algo_sid(comp,s2083643)),iz(algo_sid(comp,s2083643))),
# 	          	          reshape= same(iz(sid(s7114825)),iz(sid(s7114825)),iz(sid(s7114825))),
# 	          	          rescale= same(mass(16),mass(16),mass(16)),
# 	          	          reposition= same(iz(locX(25)),iz(locX(25)),iz(locX(25))),
# 	          	          repaint= same(pen([cc(green,1)]),pen([cc(green,1)]),pen([cc(green,1)]))]),
# 	          	     step(4), relax([ending(balanced(_))]),ctx(in_out),
# 	          	     example(trn+1),testid(v(e41c6fd3)),
# 	          	     how( in_out(
# 	          	             i_opts(shapes(none),count_equ(_),colors(each),dirs(nsew),incl_bg(false)),
# 	          	             i_opts(shapes(none),count_equ(_),colors(each),dirs(nsew),incl_bg(false))))],
# 	          	   [ rot2D(sameR),
# 	          	     iz(algo_sid(norm,s5507379)),
# 	          	     iz(algo_sid(comp,s2083643)), iz(sid(s7114825)),mass(16),iz(locX(25)),
# 	          	     pen([cc(green,1)]),
# 	          	     always( of_obj( iz(locY(J)),
# 	          	               2#=9-7,K#=J+2,
# 	          	               [ iz(locX(25)),
# 	          	                 pen([cc(green,1)])])),
# 	          	     iz( info( of_obj( iz(locY(J)),
# 	          	                 2#=9-7,K#=J+2,
# 	          	                 [ iz(locX(25)),
# 	          	                   pen([cc(green,1)])])))],
# 	          	   copy_object_n_changes(1,0..inf,[reposition],[iz(locY(K))]))
#  _________________________________________________________________________________
#
# 	          	_ :
# 	          	  of_obj( iz(locY(K)),
# 	          	    2#=9-7,K#=J+2,
# 	          	    [ iz(locX(25)),
# 	          	      pen([cc(green,1)])])
# 	          		           	:-
# 	          		           		              	[ iz( info( [ step(4), relax([ending(balanced(_))]),ctx(in_out),
# 	          		           		              	              example(trn+1),testid(v(e41c6fd3)),
# 	          		           		              	              how( in_out(
# 	          		           		              	                      i_opts(shapes(none),count_equ(_),colors(each),dirs(nsew),incl_bg(false)),
# 	          		           		              	                      i_opts(shapes(none),count_equ(_),colors(each),dirs(nsew),incl_bg(false))))])),
# 	          		           		              	  iz( info( of_obj( iz(locY(K)),
# 	          		           		              	              2#=9-7,K#=J+2,
# 	          		           		              	              [ iz(locX(25)),
# 	          		           		              	                pen([cc(green,1)])]))),
# 	          		           		              	  iz(info(birth(i_opts(shapes(none),count_equ(_),colors(each),dirs(nsew),incl_bg(false)))))],
# 	          		           		              	rot2D(sameR),
# 	          		           		              	pen([cc(cyan,1)]),
# 	          		           		              	mass(16),
# 	          		           		              	iz( ngrid( [ [ _,_,*,_,_],
# 	          		           		              	             [ *,_,*,_,*],
# 	          		           		              	             [ *,*,*,*,*],
# 	          		           		              	             [ *,*,_,*,*]])),
# 	          		           		              	grid_ops(norm,[c_r(copy_row_ntimes(3,2))]),
# 	          		           		              	cc(fg,16),
# 	          		           		              	iz(cenGX(6)),
# 	          		           		              	iz(cenGY(8)),
# 	          		           		              	always(iz(locY(J))),
# 	          		           		              	iz(locX(5)),
# 	          		           		              	area(24),
# 	          		           		              	iz(algo_sid(norm,s5507379)),
# 	          		           		              	iz(sid(s7114825)),
# 	          		           		              	   	 shape_rep( grav, [
# 	          		           		              	           point_03_01, point_04_01,point_01_02,point_03_02,
# 	          		           		              	           point_04_02,point_06_02,point_01_03,
# 	          		           		              	           point_02_03,point_03_03,point_04_03,
# 	          		           		              	           point_05_03,point_06_03,point_01_04,
# 	          		           		              	           point_02_04,point_05_04,point_06_04]),
# 	          		           		              	   	 vis2D(6,4),
# 	          		           		              	   	 loc2D(5,7),
# 	          		           		              	   	 localpoints( [ 'cyan'-point_01_02, cyan-point_01_03,cyan-point_01_04,
# 	          		           		              	                        cyan-point_02_03,cyan-point_02_04,
# 	          		           		              	                        cyan-point_03_01,cyan-point_03_02,
# 	          		           		              	                        cyan-point_03_03,cyan-point_04_01,
# 	          		           		              	                        cyan-point_04_02,cyan-point_04_03,
# 	          		           		              	                        cyan-point_05_03,cyan-point_05_04,
# 	          		           		              	                        cyan-point_06_02,cyan-point_06_03,
# 	          		           		              	                        'cyan'-point_06_04]),
# 	          		           		              	   	 grid( [ [   _   ,  _   ,'cyan','cyan',  _   ,  _   ],
# 	          		           		              	                 [ 'cyan',  _   ,'cyan','cyan',  _   ,'cyan'],
# 	          		           		              	                 [ 'cyan','cyan','cyan','cyan','cyan','cyan'],
# 	          		           		              	                 [ 'cyan','cyan',  _   ,  _   ,'cyan','cyan']]),
# 	          		           		              	   	 globalpoints( [ 'cyan'-point_05_08, cyan-point_05_09,cyan-point_05_10,
# 	          		           		              	                         cyan-point_06_09,cyan-point_06_10,
# 	          		           		              	                         cyan-point_07_07,cyan-point_07_08,
# 	          		           		              	                         cyan-point_07_09,cyan-point_08_07,
# 	          		           		              	                         cyan-point_08_08,cyan-point_08_09,
# 	          		           		              	                         cyan-point_09_09,cyan-point_09_10,
# 	          		           		              	                         cyan-point_10_08,cyan-point_10_09,
# 	          		           		              	                         'cyan'-point_10_10]),
# 	          		           		              	   	 grid_ops(comp,[c_r(and(copy_insert(2,[4]),copy_insert(1,[5])))]),
# 	          		           		              	   	 grid_rep( comp,  [ [   bg  ,  bg  ,'cyan'],
# 	          		           		              	                            [ 'cyan',  bg  ,'cyan'],
# 	          		           		              	                            [ 'cyan','cyan','cyan'],
# 	          		           		              	                            [ 'cyan','cyan',  bg  ]]),
# 	          		           		              	   	 grid_rep( norm,  [ [   bg  ,  bg  ,'cyan',  bg  ,  bg  ],
# 	          		           		              	                            [ 'cyan',  bg  ,'cyan',  bg  ,'cyan'],
# 	          		           		              	                            [ 'cyan','cyan','cyan','cyan','cyan'],
# 	          		           		              	                            [ 'cyan','cyan',  bg  ,'cyan','cyan']]),
# 	          		           		              	   	 changes([]),
# 	          		           		              	   	 iz(fg_or_bg(iz_fg)),
# 	          		           		              	   	 iz(i_o(input)),
# 	          		           		              	   	 occurs_in_links(sees,2),
# 	          		           		              	   	 links_count(sees,2),
# 	          		           		              	   	 cc(bg,0),
# 	          		           		              	   	 global2G(23,13),
# 	          		           		              	   	 iz(sizeGX(4)),
# 	          		           		              	   	 iz(sizeGY(3)),
# 	          		           		              	   	 sym_counts('sym_extend_-_/_\\_|',0),
# 	          		           		              	   	 sym_counts('sym_node_*_+_@_~',13),
# 	          		           		              	   	 rotSize2D(grav,6,4),
# 	          		           		              	   	 unique_colors_count(1),
# 	          		           		              	   	 empty_area(8),
# 	          		           		              	   	 giz(grid_sz(30,14)),
# 	          		           		              	   	 iz(algo_sid(comp,s2083643)),
# 	          		           		              	   	 giz(g(in)),
# 	          		           		              	   	 giz(testid(v(e41c6fd3))),
# 	          		           		              	   	 giz(example_num(trn+1)),
# 	          		           		              	   	 giz(testid_example_io(v(e41c6fd3)>(trn+1)*(in))),
# 	          		           		              	   	 oid(o_ҕ_488_v_e41c6fd3_trn_1_in),
# 	          		           		              	   	 giz(iv(488)),
# 	          		           		              	   	 giz(glyph(ҕ)),
# 	          		           		              	   	 giz(gid(v_e41c6fd3_trn_1_in)),
# 	          		           		              	   	 giz(gido(v_e41c6fd3_trn_1_in)),
# 	          		           		              	   	 pg(_,pen(_),rank1,2),
# 	          		           		              	   	 pg(_,pen(_),rankLS,3),
# 	          		           		              	   	 pg(_,cc(bg,_),rank1,1),
# 	          		           		              	   	 pg(_,cc(bg,_),rankLS,4),
# 	          		           		              	   	 pg(_,iz(cenGX(_)),rank1,1),
# 	          		           		              	   	 pg(_,iz(cenGX(_)),rankLS,4),
# 	          		           		              	   	 pg(_,iz(cenGY(_)),rank1,2),
# 	          		           		              	   	 pg(_,iz(cenGY(_)),rankLS,3),
# 	          		           		              	   	 pg(_,iz(locY(_)),rank1,2),
# 	          		           		              	   	 pg(_,iz(locY(_)),rankLS,3),
# 	          		           		              	   	 pg(_,iz(locX(_)),rank1,1),
# 	          		           		              	   	 pg(_,iz(locX(_)),rankLS,4).
#  _________________________________________________________________________________
# 	    	info =  (6)
# 	             	   	 step(5)
# 	             	   	 relax([ending(balanced(_))])
# 	             	   	 ctx(in_out)
# 	             	   	 example(trn+1)
# 	             	   	 testid(v(e41c6fd3))
# 	             	how( in_out(
# 	             	        i_opts(shapes(none),count_equ(_),colors(each),dirs(nsew),incl_bg(false)),
# 	             	        i_opts(shapes(none),count_equ(_),colors(each),dirs(nsew),incl_bg(false))))
# 	    	prevRules =
# 	          	count(13)
# 	    	narrativeIn =  (6)
# 	             	copy_object_n_changes(1,0,inf,3)
# 	             	copy_object_n_changes(2,0,inf,0)
# 	             	copy_object_n_changes(3,0,inf,0)
# 	             	add_dependant_scenery(0,inf,0)
# 	             	add_independant_scenery(0,inf,0)
# 	             	balanced_or_delete_leftovers(_,0)
# 	    	in(3) =
# 	          	   _____________________________________________________________
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                                                     Յ Յ     |
# 	          	  |                                                 Յ   Յ Յ   Յ |
# 	          	  |                             Ꮶ Ꮶ                 Յ Յ Յ Յ Յ Յ |
# 	          	  |                         Ꮶ   Ꮶ Ꮶ   Ꮶ             Յ Յ     Յ Յ |
# 	          	  |                         Ꮶ Ꮶ Ꮶ Ꮶ Ꮶ Ꮶ                         |
# 	          	  |                         Ꮶ Ꮶ     Ꮶ Ꮶ                         |
# 	          	   ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#
# 	    	out(3) =
# 	          	   _____________________________________________________________
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                                                             |
# 	          	  |                             Ᏻ Ᏻ                     ԡ ԡ     |
# 	          	  |                         Ᏻ   Ᏻ Ᏻ   Ᏻ             ԡ   ԡ ԡ   ԡ |
# 	          	  |                         Ᏻ[
# %~ no_more(copy_object_n_changes(1,0,inf,6))
# %~ no_more(copy_object_n_changes(2,0,inf,0))
# %~ no_more(copy_object_n_changes(3,0,inf,0))
# %~ no_more(add_dependant_scenery(0,inf,0))
# %~ no_more(add_independant_scenery(0,inf,0))

# %%
np.set_printoptions(linewidth=110)

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %%
for soln in prolog.query("print_test"): print()
